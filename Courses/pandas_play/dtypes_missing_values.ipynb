# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 50
reviews = pd.read_csv("winemag_small.csv", index_col=0)

reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
# convert column type
reviews.points.astype('float64')
# Out:
# 0      87.0
# 1      87.0
# 2      87.0
# 3      87.0
# 4      87.0
#        ...
# 349    97.0
# 350    97.0
# 351    96.0
# 352    96.0
# 353    96.0
# Name: points, Length: 354, dtype: float64

# %%
# display empty data
reviews[pd.isnull(reviews.price)]
# Out:
#           country                                        description  \
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 13          Italy  This is dominated by oak and oak-driven aromas...
# 30         France  Red cherry fruit comes laced with light tannin...
# 31          Italy  Merlot and Nero d'Avola form the base for this...
# 32          Italy  Part of the extended Calanìca series, this Gri...
# 50          Italy  This blend of Nero d'Avola and Syrah opens wit...
# 54          Italy  A blend of Nero d'Avola and Nerello Mascalese,...
# 79       Portugal  Grown on the sandy soil of Tejo, the wine is t...
# 137  South Africa  This is great Chenin Blanc, wood fermented but...
# 159         Italy  Intense aromas of ripe red berry, menthol, esp...
# 163        France  Produced from vineyards donated to a charitabl...
# 182         Italy  Loaded with bold, ripe fruit, exotic spice and...
# 194         Italy  Here's a traditional Chianti Classico with pre...
# ...

# %%
# replace missing fields
reviews.region_2.fillna("Unknown")
# Out:
# 0                Unknown
# 1                Unknown
# 2      Willamette Valley
# 3                Unknown
# 4      Willamette Valley
#              ...
# 349              Unknown
# 350              Unknown
# 351              Unknown
# 352               Sonoma
# 353              Unknown
# Name: region_2, Length: 354, dtype: object

# %%
# change specific values
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#             ...
# 349            @JoeCz
# 350           @kerino
# 351    @worldwineguys
# 352           @vboone
# 353        @vossroger
# Name: taster_twitter_handle, Length: 354, dtype: object

# %%
reviews.region_1.fillna("Unknown").value_counts().sort_values(ascending=False)

#reviews.groupby(['region_1']).description.agg([len]).sort_values('len', ascending=False)

# reviews.region_1.fillna("Unknown")
# reviews_unk.groupby(['region_1']).size().sort_values(ascending=False)
# Out:
# Unknown          66
# Napa Valley      23
# Sicilia          12
# Alsace           12
# Toscana          10
#                  ..
# Montsant          1
# St. Helena        1
# Saint-Estèphe     1
# Arbois            1
# Montrachet        1
# Name: region_1, Length: 132, dtype: int64
