# %%
import pandas as pd

pd.options.display.max_rows = 50
reviews = pd.read_csv("winemag_small.csv", index_col=0)

reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# ..         ...                                                ...
# 349  Australia  RunRig is always complex, and the 2012 doesn't...
# 350      Italy  After a few minutes in the glass, this stunnin...
# 351    Hungary  This amber-colored Hungarian stunner has ether...
# 352         US  Citrus-kissed saltiness lies at the core of th...
# 353     France  This beautiful, rich wine has yellow fruits an...
#
#                             designation  score  price           province  \
# 0                          Vulkà Bianco     87    NaN  Sicily & Sardinia
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                country                                        description  \
# firstEntry       Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry   Portugal  This is ripe and fruity, a wine that is smooth...
# 2                   US  Tart and snappy, the flavors of lime flesh and...
# 3                   US  Pineapple rind, lemon pith and orange blossom ...
# 4                   US  Much like the regular bottling from 2012, this...
# ...                ...                                                ...
# 349          Australia  RunRig is always complex, and the 2012 doesn't...
# 350              Italy  After a few minutes in the glass, this stunnin...
# 351            Hungary  This amber-colored Hungarian stunner has ether...
# 352                 US  Citrus-kissed saltiness lies at the core of th...
# 353             France  This beautiful, rich wine has yellow fruits an...
#
#                                     designation  points  price  \
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields    country                                        description  \
# wines
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 1        Portugal  This is ripe and fruity, a wine that is smooth...
# 2              US  Tart and snappy, the flavors of lime flesh and...
# 3              US  Pineapple rind, lemon pith and orange blossom ...
# 4              US  Much like the regular bottling from 2012, this...
# ...           ...                                                ...
# 349     Australia  RunRig is always complex, and the 2012 doesn't...
# 350         Italy  After a few minutes in the glass, this stunnin...
# 351       Hungary  This amber-colored Hungarian stunner has ether...
# 352            US  Citrus-kissed saltiness lies at the core of th...
# 353        France  This beautiful, rich wine has yellow fruits an...
#
# fields                         designation  points  price           province  \
# wines
# ...

# %%
# concatenating
wines_small = pd.read_csv("winemag_small.csv", index_col=0)
wines_alternate = pd.read_csv("winemag_alternative.csv", index_col=0)

pd.concat([wines_small, wines_alternate])
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2         US  Tart and snappy, the flavors of lime flesh and...
# 3         US  Pineapple rind, lemon pith and orange blossom ...
# 4         US  Much like the regular bottling from 2012, this...
# ..       ...                                                ...
# 68        US  Funky, with mushroom and sweaty leather aromas...
# 69        US  This is a dry, elegant young Pinot Noir. It's ...
# 70        US  A big burly Syrah from this Temecula producer ...
# 71        US  The blackberry, blueberry, bacon, pepper and s...
# 72     Chile  Cola, root beer and other earthy aromas open u...
#
#                            designation  points  price           province  \
# 0                         Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
left = wines_small.set_index(['country', 'taster_twitter_handle'])
right = wines_alternate.set_index(['country', 'taster_twitter_handle'])

left.join(right, lsuffix='_first', rsuffix='_second')
# Out:
#                                                                  description_first  \
# country   taster_twitter_handle
# Argentina @wineschach            Baked plum, molasses, balsamic vinegar and che...
#           @wineschach            Baked plum, molasses, balsamic vinegar and che...
#           @wineschach            Baked plum, molasses, balsamic vinegar and che...
#           @wineschach            Baked plum, molasses, balsamic vinegar and che...
#           @wineschach            Baked plum, molasses, balsamic vinegar and che...
# ...                                                                            ...
# US        NaN                    This Rhône-style blend is a little rustic and ...
#           NaN                    This Rhône-style blend is a little rustic and ...
#           NaN                    This Rhône-style blend is a little rustic and ...
#           NaN                    This Rhône-style blend is a little rustic and ...
# ...
