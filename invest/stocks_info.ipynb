# %%
import yfinance as yf
import mplfinance as mpf
data = yf.download("NET", start="2022-01-01", end="2022-10-27")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(data, type="renko")
